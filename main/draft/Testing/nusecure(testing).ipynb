# %%
from flask import Flask, render_template, request, redirect, url_for
import pandas as pd

app = Flask(__name__)

# %%
@app.route('/', methods=['GET', 'POST'])
def home():
    if request.method == 'POST':
        user_id = request.form['UserID']
        password = request.form['Password']  

        if user_id == 'security' and password == 'security':
            return redirect(url_for('security'))
        elif user_id == 'analytics' and password == 'analytics':
            return redirect(url_for('analytics'))
        else:
            return "Invalid UserID or Password"
    return render_template('home.html')

def retrieve_security_table():
    import os
    print(os.getcwd())
    df = pd.read_csv('data/data.csv')
    # df = df.append(new, ignore_index=True)
    # df.to_csv('../data/data.csv', index=False)
    return df

# %%
import os
os.getcwd()
# Out:
# '/Users/chloetan/Desktop/DSA3101/proj/main/draft/Testing'

# %%
retrieve_security_table()
# Out:
# /Users/chloetan/Desktop/DSA3101/proj/main/draft/Testing
#       IncidentID                                       Description Priority  \
# 0           7831                   LOST AND FOUND at 5 KR BUNGALOW   Normal
# 1           7761  DAMAGED PROPERTY at RAFFLES HALL (COMMUNAL HALL)     High
# 2           8191         DAMAGED PROPERTY at TMSI-ST JOHN'S ISLAND     High
# 3           8481           LOST AND FOUND at CTR FOR LIFE SCIENCES   Normal
# 4           7708                 DAMAGED PROPERTY at 5 KR BUNGALOW     High
# ...          ...                                               ...      ...
# 8665        1641                LOST AND FOUND at 14A PGP BUNGALOW   Normal
# 8666         719       SEXUAL INCIDENTS at COLLEGE OF A&P TAN -MPH     High
# 8667        1199   EMERGENCY INCIDENTS at PGP RESIDENCES CANTEEN 2     High
# 8668         175             LOST AND FOUND at ENGINEERING BLOCK 1   Normal
# 8669        1268          LOST AND FOUND at RAFFLES HALL (BLOCK A)   Normal
#
#                 Incidents Location                      Building  Latitude  \
# 0          LOST AND FOUND       KR                 5 KR BUNGALOW  1.294573
# 1        DAMAGED PROPERTY      YIH  RAFFLES HALL (COMMUNAL HALL)  1.300003
# 2        DAMAGED PROPERTY      OTH         TMSI-ST JOHN'S ISLAND  1.217103
# 3          LOST AND FOUND      FOS         CTR FOR LIFE SCIENCES  1.294496
# 4        DAMAGED PROPERTY       KR                 5 KR BUNGALOW  1.294573
# ...                   ...      ...                           ...       ...
# 8665       LOST AND FOUND      PGP              14A PGP BUNGALOW  1.293265
# 8666     SEXUAL INCIDENTS    UTown       COLLEGE OF A&P TAN -MPH  1.307802
# 8667  EMERGENCY INCIDENTS      PGP      PGP RESIDENCES CANTEEN 2  1.290620
# 8668       LOST AND FOUND      CDE           ENGINEERING BLOCK 1  1.298762
# 8669       LOST AND FOUND      YIH        RAFFLES HALL (BLOCK A)  1.299678
#
#        Longitude  User          FirstUpdate         LatestUpdate Status
# 0     103.779646  sec3  2023-12-29 01:59:00  2023-12-31 16:06:07  Close
# 1     103.773935  sec5  2023-12-19 21:04:00  2023-12-26 11:15:30  Close
# 2     103.850106  sec5  2023-12-18 22:03:00  2023-12-24 19:59:38  Close
# 3     103.780914  sec2  2023-12-19 21:12:00  2023-12-23 02:48:30  Close
# 4     103.779646  sec5  2023-12-16 06:24:00  2023-12-22 08:03:56  Close
# ...          ...   ...                  ...                  ...    ...
# 8665  103.777459  sec2  2018-08-26 21:19:00  2018-08-29 22:34:15  Close
# 8666  103.773246  sec1  2018-08-23 09:21:00  2018-08-29 02:26:51  Close
# 8667  103.781695  sec2  2018-08-27 01:27:00  2018-08-28 12:58:15  Close
# 8668  103.771079  sec2  2018-08-07 04:58:00  2018-08-10 06:27:51  Close
# 8669  103.773247  sec4  2018-08-04 05:37:00  2018-08-07 09:26:34  Close
#
# [8670 rows x 12 columns]

# %%
@app.route('/security', methods=['GET', 'POST'])
def security():
    data = retrieve_security_table()
    columns = data.columns.tolist()
    print(columns)
    data_dict = data.to_dict(orient='records')
    return render_template('security_table.html',columns=columns,data=data_dict)

@app.route('/analytics', methods=['GET'])
def analytics():
    return render_template('analytics.html')

if __name__ == "__main__":
    app.run(host='0.0.0.0', port=5002, debug=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/chloetan/Desktop/DSA3101/proj/main/draft/Testing/nusecure(testing).ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/Users/chloetan/Desktop/DSA3101/proj/main/draft/Testing/nusecure%28testing%29.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> @app.route('/security', methods=['GET', 'POST'])
# ----> <a href='vscode-notebook-cell:/Users/chloetan/Desktop/DSA3101/proj/main/draft/Testing/nusecure%28testing%29.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> def security():
#       <a href='vscode-notebook-cell:/Users/chloetan/Desktop/DSA3101/proj/main/draft/Testing/nusecure%28testing%29.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     data = retrieve_security_table()
#       <a href='vscode-notebook-cell:/Users/chloetan/Desktop/DSA3101/proj/main/draft/Testing/nusecure%28testing%29.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a>     columns = data.columns.tolist()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/flask/scaffold.py:435, in Scaffold.route.<locals>.decorator(f)
#     433 def decorator(f: T_route) -> T_route:
#     434     endpoint = options.pop("endpoint", None)
# --> 435     self.add_url_rule(rule, endpoint, f, **options)
#     436     return f
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/flask/scaffold.py:50, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      48 def wrapper_func(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
#      49     self._check_setup_finished(f_name)
# ---> 50     return f(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/flask/app.py:1059, in Flask.add_url_rule(self, rule, endpoint, view_func, provide_automatic_options, **options)
#    1057 old_func = self.view_functions.get(endpoint)
#    1058 if old_func is not None and old_func != view_func:
# -> 1059     raise AssertionError(
#    1060         "View function mapping is overwriting an existing"
#    1061         f" endpoint function: {endpoint}"
#    1062     )
#    1063 self.view_functions[endpoint] = view_func
#
# AssertionError: View function mapping is overwriting an existing endpoint function: security
